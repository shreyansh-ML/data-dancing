# %% [markdown]
# https://www.analyticsvidhya.com/blog/2018/04/a-comprehensive-guide-to-understand-and-implement-text-classification-in-python/

# %% [markdown]
# https://towardsdatascience.com/email-spam-detection-1-2-b0e06a5c0472

# %% [markdown]
# https://machinelearningmastery.com/prepare-text-data-machine-learning-scikit-learn/

# %% [markdown]
# steps to be followed:
# 1. convert all letters to lower/upper case
# 2. removing numbers,puctuations,white space,hyperlink
# 3. removing removing stop words such as a, about, above, down, doing
# 4. Word Stemming
# 5. Word lemmatization

# %%
import os

# %%
import pandas as pd
import numpy as np

# %%
curr_dir=os.path.abspath(os.path.curdir)

# %%
os.path.join(curr_dir,"..",'..','..','DATA','apache-spam','')
# Out:
# 'C:\\Users\\shsubham\\program\\data-dancing\\gerone\\Classification\\..\\..\\..\\DATA\\apache-spam\\'

# %%
os.path.curdir
# Out:
# '.'

# %%
path=r'C:\Users\shsubham\program\DATA\apache-spam\spam-ham'

# %%
easy_ham_path=os.path.join(path,"easy_ham")

# %%
hard_ham_path=os.path.join(path,"hard_ham")

# %%
spam_path=os.path.join(path,"spam")

# %%
#(os.listdir(easy_ham_path))
# Out:
# ['0001.ea7e79d3153e7469e7a9c3e0af6a357e',
#  '0002.b3120c4bcbf3101e661161ee7efcb8bf',
#  '0003.acfc5ad94bbd27118a0d8685d18c89dd',
#  '0004.e8d5727378ddde5c3be181df593f1712',
#  '0005.8c3b9e9c0f3f183ddaf7592a11b99957',
#  '0006.ee8b0dba12856155222be180ba122058',
#  '0007.c75188382f64b090022fa3b095b020b0',
#  '0008.20bc0b4ba2d99aae1c7098069f611a9b',
#  '0009.435ae292d75abb1ca492dcc2d5cf1570',
#  '0010.4996141de3f21e858c22f88231a9f463',
#  '0011.07b11073b53634cff892a7988289a72e',
#  '0012.d354b2d2f24d1036caf1374dd94f4c94',
#  '0013.ff597adee000d073ae72200b0af00cd1',
#  '0014.532e0a17d0674ba7a9baa7b0afe5fb52',
#  '0015.a9ff8d7550759f6ab62cc200bdf156e7',
#  '0016.d82758030e304d41fb3f4ebbb7d9dd91',
#  '0017.d81093a2182fc9135df6d9158a8ebfd6',
#  '0018.ba70ecbeea6f427b951067f34e23bae6',
#  '0019.a8a1b2767e83b3be653e4af0148e1897',
#  '0020.ef397cef16f8041242e3b6560e168053',
#  '0021.f8e73bdba7277d967af4d561f0402129',
#  '0022.7241da4491c49b50c0470a3638ee35c4',
# ...

# %%
email_feature=[]
label=[]
category=[]
file_name=[]
word_list={}

# %%
import email

# %%
for file in os.listdir(easy_ham_path):
    filename=os.path.join(easy_ham_path,file)
    with open(filename,'r') as f:
        content=f.read()
        body=email.message_from_string(content)
        print(body)
        #print(email.header(content))
    break
# Out:
# Return-Path: <exmh-workers-admin@example.com>
# Delivered-To: zzzz@localhost.netnoteinc.com
# Received: from localhost (localhost [127.0.0.1])
# 	by phobos.labs.netnoteinc.com (Postfix) with ESMTP id D03E543C36
# 	for <zzzz@localhost>; Thu, 22 Aug 2002 07:36:16 -0400 (EDT)
# Received: from phobos [127.0.0.1]
# 	by localhost with IMAP (fetchmail-5.9.0)
# 	for zzzz@localhost (single-drop); Thu, 22 Aug 2002 12:36:16 +0100 (IST)
# Received: from listman.example.com (listman.example.com [66.187.233.211]) by
#     dogma.slashnull.org (8.11.6/8.11.6) with ESMTP id g7MBYrZ04811 for
#     <zzzz-exmh@example.com>; Thu, 22 Aug 2002 12:34:53 +0100
# Received: from listman.example.com (localhost.localdomain [127.0.0.1]) by
#     listman.redhat.com (Postfix) with ESMTP id 8386540858; Thu, 22 Aug 2002
#     07:35:02 -0400 (EDT)
# Delivered-To: exmh-workers@listman.example.com
# Received: from int-mx1.corp.example.com (int-mx1.corp.example.com
# ...

# %%
mess=email.message.EmailMessage()

# %%
type(body)
# Out:
# email.message.Message

# %%
mess.get_body(preferencelist='plain')

# %%
print(body.get_content_subtype())
# Out:
# plain

# %%
import re

# %%
pattern = re.compile("o[gh]")

# %%
for i in pattern:
    print(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-72715d8a4e3c> in <module>
# ----> 1 for i in pattern:
#       2     print(i)
#
# TypeError: '_sre.SRE_Pattern' object is not iterable

# %%
type(body)
# Out:
# email.message.Message

# %%
ct=body.get_payload()

# %%
body_pp=ct.lower()

# %%
body_pp1 = re.sub(r"<[^<>]+>", " html ", body_pp)

# %%
print(body_pp)
# Out:
#     date:        wed, 21 aug 2002 10:54:46 -0500
#     from:        chris garrigues <cwg-dated-1030377287.06fa6d@deepeddy.com>
#     message-id:  <1029945287.4797.tmda@deepeddy.vircio.com>
#
#
#   | i can't reproduce this error.
#
# for me it is very repeatable... (like every time, without fail).
#
# this is the debug log of the pick happening ...
#
# 18:19:03 pick_it {exec pick +inbox -list -lbrace -lbrace -subject ftp -rbrace -rbrace} {4852-4852 -sequence mercury}
# 18:19:03 exec pick +inbox -list -lbrace -lbrace -subject ftp -rbrace -rbrace 4852-4852 -sequence mercury
# 18:19:04 ftoc_pickmsgs {{1 hit}}
# 18:19:04 marking 1 hits
# 18:19:04 tkerror: syntax error in expression "int ...
#
# note, if i run the pick command by hand ...
#
# delta$ pick +inbox -list -lbrace -lbrace -subject ftp -rbrace -rbrace  4852-4852 -sequence mercury
# 1 hit
#
# that's where the "1 hit" comes from (obviously).  the version of nmh i'm
# using is ...
#
# delta$ pick -version
# ...

# %%
body_pp2 = re.sub(r"[0-9]+", " number ", body_pp1)

# %%
print(body_pp2)
# Out:
#     date:        wed,  number  aug  number   number : number : number  - number
#     from:        chris garrigues  html
#     message-id:   html
#
#
#   | i can't reproduce this error.
#
# for me it is very repeatable... (like every time, without fail).
#
# this is the debug log of the pick happening ...
#
#  number : number : number  pick_it {exec pick +inbox -list -lbrace -lbrace -subject ftp -rbrace -rbrace} { number - number  -sequence mercury}
#  number : number : number  exec pick +inbox -list -lbrace -lbrace -subject ftp -rbrace -rbrace  number - number  -sequence mercury
#  number : number : number  ftoc_pickmsgs {{ number  hit}}
#  number : number : number  marking  number  hits
#  number : number : number  tkerror: syntax error in expression "int ...
#
# note, if i run the pick command by hand ...
#
# delta$ pick +inbox -list -lbrace -lbrace -subject ftp -rbrace -rbrace   number - number  -sequence mercury
#  number  hit
#
# ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
# list of text documents
text = ["The quick brown fox jumped over the lazy dog.",
		"The dog.",
		"The fox"]
# create the transform
vectorizer = TfidfVectorizer()
# tokenize and build vocab
vectorizer.fit(text)
# summarize
print(vectorizer.vocabulary_)
print(vectorizer.idf_)
# encode document
vector = vectorizer.transform([text[0]])
# summarize encoded vector
print(vector.shape)
print(vector.toarray())
# Out:
# {'the': 7, 'quick': 6, 'brown': 0, 'fox': 2, 'jumped': 3, 'over': 5, 'lazy': 4, 'dog': 1}
# [1.69314718 1.28768207 1.28768207 1.69314718 1.69314718 1.69314718
#  1.69314718 1.        ]
# (1, 8)
# [[0.36388646 0.27674503 0.27674503 0.36388646 0.36388646 0.36388646
#   0.36388646 0.42983441]]
